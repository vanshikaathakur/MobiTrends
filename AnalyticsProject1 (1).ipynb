# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\nt397\Downloads\Mobiles Dataset (2025).xlsx")
df
# Out:
#     Company Name            Model Name Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174g   6GB             12MP
# 1          Apple       iPhone 16 256GB          174g   6GB             12MP
# 2          Apple       iPhone 16 512GB          174g   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203g   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203g   6GB             12MP
# ..           ...                   ...           ...   ...              ...
# 925         Poco          Pad 5G 128GB          571g   8GB              8MP
# 926         Poco          Pad 5G 256GB          571g   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239g  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239g  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239g  12GB  10MP, 4MP (UDC)
#
# ...

# %%
import numpy as np
df['Launched Price (Pakistan)'] = df['Launched Price (Pakistan)'].replace(
    ['Not available', 'N/A', 'null', 'NaN', 'missing', ''], 0
)

# %%
df['Launched Price (India)'] = df['Launched Price (India)'].replace(
    ['Not available', 'N/A', 'null', 'NaN', 'missing', ''], 0
)

# %%
df['Launched Price (China)'] = df['Launched Price (China)'].replace(
    ['Not available', 'N/A', 'null', 'NaN', 'missing', ''], 0
)

# %%
df['Launched Price (USA)'] = df['Launched Price (USA)'].replace(
    ['Not available', 'N/A', 'null', 'NaN', 'missing', ''], 0
)

# %%
df['Launched Price (Dubai)'] = df['Launched Price (Dubai)'].replace(
    ['Not available', 'N/A', 'null', 'NaN', 'missing', ''], 0
)

# %%
df
# Out:
#     Company Name            Model Name Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174g   6GB             12MP
# 1          Apple       iPhone 16 256GB          174g   6GB             12MP
# 2          Apple       iPhone 16 512GB          174g   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203g   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203g   6GB             12MP
# ..           ...                   ...           ...   ...              ...
# 925         Poco          Pad 5G 128GB          571g   8GB              8MP
# 926         Poco          Pad 5G 256GB          571g   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239g  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239g  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239g  12GB  10MP, 4MP (UDC)
#
# ...

# %%
df.isnull()
# Out:
#      Company Name  Model Name  Mobile Weight    RAM  Front Camera  \
# 0           False       False          False  False         False
# 1           False       False          False  False         False
# 2           False       False          False  False         False
# 3           False       False          False  False         False
# 4           False       False          False  False         False
# ..            ...         ...            ...    ...           ...
# 925         False       False          False  False         False
# 926         False       False          False  False         False
# 927         False       False          False  False         False
# 928         False       False          False  False         False
# 929         False       False          False  False         False
#
#      Back Camera  Processor  Battery Capacity  Screen Size  \
# 0          False      False             False        False
# ...

# %%
s=df['Launched Price (Pakistan)']
s
# Out:
# 0      PKR 224,999
# 1      PKR 234,999
# 2      PKR 244,999
# 3      PKR 249,999
# 4      PKR 259,999
#           ...
# 925     PKR 66,220
# 926     PKR 71,220
# 927    PKR 604,999
# 928    PKR 544,999
# 929              0
# Name: Launched Price (Pakistan), Length: 930, dtype: object

# %%
df
# Out:
#     Company Name            Model Name Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174g   6GB             12MP
# 1          Apple       iPhone 16 256GB          174g   6GB             12MP
# 2          Apple       iPhone 16 512GB          174g   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203g   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203g   6GB             12MP
# ..           ...                   ...           ...   ...              ...
# 925         Poco          Pad 5G 128GB          571g   8GB              8MP
# 926         Poco          Pad 5G 256GB          571g   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239g  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239g  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239g  12GB  10MP, 4MP (UDC)
#
# ...

# %%
g=df['Launched Price (Pakistan)']
t=list(g)
t
# Out:
# ['PKR 224,999',
#  'PKR 234,999',
#  'PKR 244,999',
#  'PKR 249,999',
#  'PKR 259,999',
#  'PKR 274,999',
#  'PKR 284,999',
#  'PKR 294,999',
#  'PKR 314,999',
#  'PKR 314,999',
#  'PKR 324,999',
#  'PKR 344,999',
#  'PKR 204,999',
#  'PKR 214,999',
#  'PKR 224,999',
#  'PKR 234,999',
#  'PKR 244,999',
#  'PKR 264,999',
#  'PKR 274,999',
#  'PKR 284,999',
#  'PKR 304,999',
#  'PKR 314,999',
#  'PKR 324,999',
#  'PKR 344,999',
#  'PKR 184,999',
#  'PKR 194,999',
#  'PKR 204,999',
#  'PKR 204,999',
#  'PKR 214,999',
#  'PKR 224,999',
#  'PKR 294,999',
#  'PKR 304,999',
#  'PKR 324,999',
#  'PKR 324,999',
#  'PKR 344,999',
#  'PKR 364,999',
#  'PKR 174,999',
#  'PKR 184,999',
#  'PKR 194,999',
#  'PKR 194,999',
#  'PKR 204,999',
#  'PKR 224,999',
#  'PKR 294,999',
#  'PKR 314,999',
#  'PKR 344,999',
#  'PKR 324,999',
#  'PKR 354,999',
#  'PKR 384,999',
#  'PKR 174,999',
#  'PKR 184,999',
#  'PKR 194,999',
#  'PKR 194,999',
#  'PKR 204,999',
#  'PKR 224,999',
#  'PKR 314,999',
# ...

# %%
p = []
for i in t:
    h = ""
    for j in str(i):  
        if j.isdigit():
            h += j
    p.append(h)

# %%
p
# Out:
# ['224999',
#  '234999',
#  '244999',
#  '249999',
#  '259999',
#  '274999',
#  '284999',
#  '294999',
#  '314999',
#  '314999',
#  '324999',
#  '344999',
#  '204999',
#  '214999',
#  '224999',
#  '234999',
#  '244999',
#  '264999',
#  '274999',
#  '284999',
#  '304999',
#  '314999',
#  '324999',
#  '344999',
#  '184999',
#  '194999',
#  '204999',
#  '204999',
#  '214999',
#  '224999',
#  '294999',
#  '304999',
#  '324999',
#  '324999',
#  '344999',
#  '364999',
#  '174999',
#  '184999',
#  '194999',
#  '194999',
#  '204999',
#  '224999',
#  '294999',
#  '314999',
#  '344999',
#  '324999',
#  '354999',
#  '384999',
#  '174999',
#  '184999',
#  '194999',
#  '194999',
#  '204999',
#  '224999',
#  '314999',
#  '334999',
#  '354999',
#  '344999',
#  '364999',
#  '384999',
#  '159999',
#  '169999',
#  '179999',
#  '219999',
#  '239999',
#  '259999',
#  '269999',
#  '289999',
#  '309999',
#  '164999',
#  '184999',
#  '219999',
#  '239999',
#  '259999',
#  '249999',
#  '269999',
# ...

# %%
df['Launched Price (Pakistan)']=p
p
# Out:
# ['224999',
#  '234999',
#  '244999',
#  '249999',
#  '259999',
#  '274999',
#  '284999',
#  '294999',
#  '314999',
#  '314999',
#  '324999',
#  '344999',
#  '204999',
#  '214999',
#  '224999',
#  '234999',
#  '244999',
#  '264999',
#  '274999',
#  '284999',
#  '304999',
#  '314999',
#  '324999',
#  '344999',
#  '184999',
#  '194999',
#  '204999',
#  '204999',
#  '214999',
#  '224999',
#  '294999',
#  '304999',
#  '324999',
#  '324999',
#  '344999',
#  '364999',
#  '174999',
#  '184999',
#  '194999',
#  '194999',
#  '204999',
#  '224999',
#  '294999',
#  '314999',
#  '344999',
#  '324999',
#  '354999',
#  '384999',
#  '174999',
#  '184999',
#  '194999',
#  '194999',
#  '204999',
#  '224999',
#  '314999',
#  '334999',
#  '354999',
#  '344999',
#  '364999',
#  '384999',
#  '159999',
#  '169999',
#  '179999',
#  '219999',
#  '239999',
#  '259999',
#  '269999',
#  '289999',
#  '309999',
#  '164999',
#  '184999',
#  '219999',
#  '239999',
#  '259999',
#  '249999',
#  '269999',
# ...

# %%
df['Launched Price (Pakistan)']=df['Launched Price (Pakistan)'].astype('int')
df
# Out:
#     Company Name            Model Name Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174g   6GB             12MP
# 1          Apple       iPhone 16 256GB          174g   6GB             12MP
# 2          Apple       iPhone 16 512GB          174g   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203g   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203g   6GB             12MP
# ..           ...                   ...           ...   ...              ...
# 925         Poco          Pad 5G 128GB          571g   8GB              8MP
# 926         Poco          Pad 5G 256GB          571g   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239g  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239g  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239g  12GB  10MP, 4MP (UDC)
#
# ...

# %%
df.shape
# Out:
# (930, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Company Name               930 non-null    object
#  1   Model Name                 930 non-null    object
#  2   Mobile Weight              930 non-null    object
#  3   RAM                        930 non-null    object
#  4   Front Camera               930 non-null    object
#  5   Back Camera                930 non-null    object
#  6   Processor                  930 non-null    object
#  7   Battery Capacity           930 non-null    object
#  8   Screen Size                930 non-null    object
#  9   Launched Price (Pakistan)  930 non-null    int32
#  10  Launched Price (India)     930 non-null    object
#  11  Launched Price (China)     930 non-null    object
#  12  Launched Price (USA)       930 non-null    object
# ...

# %%
s=df['Launched Price (Pakistan)']
s
# Out:
# 0      224999
# 1      234999
# 2      244999
# 3      249999
# 4      259999
#         ...
# 925     66220
# 926     71220
# 927    604999
# 928    544999
# 929         0
# Name: Launched Price (Pakistan), Length: 930, dtype: int32

# %%
import matplotlib.pyplot as plot

# %%
s.plot.box()
# Out:
# <Axes: >

# %%
q1=np.quantile(s,0.25)
q1
# Out:
# 54999.0

# %%
q2=np.quantile(s,0.75)
q2
# Out:
# 179999.0

# %%
h=q2-q1
h
# Out:
# 125000.0

# %%
upper=q2+(1.5*h)
upper
# Out:
# 367499.0

# %%
lower=q1-(1.5*h)
lower
# Out:
# -132501.0

# %%
p=[]
for i in s:
    if(i>lower and i<upper):
        p.append(i)
p
# Out:
# [224999,
#  234999,
#  244999,
#  249999,
#  259999,
#  274999,
#  284999,
#  294999,
#  314999,
#  314999,
#  324999,
#  344999,
#  204999,
#  214999,
#  224999,
#  234999,
#  244999,
#  264999,
#  274999,
#  284999,
#  304999,
#  314999,
#  324999,
#  344999,
#  184999,
#  194999,
#  204999,
#  204999,
#  214999,
#  224999,
#  294999,
#  304999,
#  324999,
#  324999,
#  344999,
#  364999,
#  174999,
#  184999,
#  194999,
#  194999,
#  204999,
#  224999,
#  294999,
#  314999,
#  344999,
#  324999,
#  354999,
#  174999,
#  184999,
#  194999,
#  194999,
#  204999,
#  224999,
#  314999,
#  334999,
#  354999,
#  344999,
#  364999,
#  159999,
#  169999,
#  179999,
#  219999,
#  239999,
#  259999,
#  269999,
#  289999,
#  309999,
#  164999,
#  184999,
#  219999,
#  239999,
#  259999,
#  249999,
#  269999,
#  289999,
#  149999,
#  159999,
#  179999,
#  79999,
#  89999,
#  49999,
#  59999,
#  69999,
#  79999,
#  149999,
#  169999,
#  189999,
#  219999,
#  239999,
#  259999,
#  259999,
# ...

# %%
plt.boxplot(p)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 plt.boxplot(p)
#       2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df.describe()
# Out:
#        Launched Price (Pakistan)  Launched Year
# count                 930.000000     930.000000
# mean               125301.186022    2022.193548
# std                101622.105232       1.862080
# min                     0.000000    2014.000000
# 25%                 54999.000000    2021.000000
# 50%                 84999.500000    2023.000000
# 75%                179999.000000    2024.000000
# max                604999.000000    2025.000000

# %%
g=df['Launched Price (India)']
t=list(g)
t
# Out:
# ['INR 79,999',
#  'INR 84,999',
#  'INR 89,999',
#  'INR 89,999',
#  'INR 94,999',
#  'INR 104,999',
#  'INR 99,999',
#  'INR 104,999',
#  'INR 114,999',
#  'INR 109,999',
#  'INR 114,999',
#  'INR 124,999',
#  'INR 74,999',
#  'INR 79,999',
#  'INR 89,999',
#  'INR 84,999',
#  'INR 94,999',
#  'INR 104,999',
#  'INR 99,999',
#  'INR 109,999',
#  'INR 119,999',
#  'INR 114,999',
#  'INR 124,999',
#  'INR 134,999',
#  'INR 69,999',
#  'INR 74,999',
#  'INR 84,999',
#  'INR 79,999',
#  'INR 84,999',
#  'INR 94,999',
#  'INR 109,999',
#  'INR 119,999',
#  'INR 134,999',
#  'INR 124,999',
#  'INR 134,999',
#  'INR 144,999',
#  'INR 69,900',
#  'INR 74,900',
#  'INR 84,900',
#  'INR 74,900',
#  'INR 84,900',
#  'INR 94,900',
#  'INR 119,900',
#  'INR 129,900',
#  'INR 139,900',
#  'INR 129,900',
#  'INR 139,900',
#  'INR 149,900',
#  'INR 69,900',
#  'INR 74,900',
#  'INR 84,900',
#  'INR 74,900',
#  'INR 84,900',
#  'INR 94,900',
#  'INR 119,900',
#  'INR 129,900',
#  'INR 139,900',
# ...

# %%
p=[]
for i in t:
    h=""
    
    for j in i:
        if(j.isdigit()):
            h=h+j
    p.append(h)

# %%
p
# Out:
# ['79999',
#  '84999',
#  '89999',
#  '89999',
#  '94999',
#  '104999',
#  '99999',
#  '104999',
#  '114999',
#  '109999',
#  '114999',
#  '124999',
#  '74999',
#  '79999',
#  '89999',
#  '84999',
#  '94999',
#  '104999',
#  '99999',
#  '109999',
#  '119999',
#  '114999',
#  '124999',
#  '134999',
#  '69999',
#  '74999',
#  '84999',
#  '79999',
#  '84999',
#  '94999',
#  '109999',
#  '119999',
#  '134999',
#  '124999',
#  '134999',
#  '144999',
#  '69900',
#  '74900',
#  '84900',
#  '74900',
#  '84900',
#  '94900',
#  '119900',
#  '129900',
#  '139900',
#  '129900',
#  '139900',
#  '149900',
#  '69900',
#  '74900',
#  '84900',
#  '74900',
#  '84900',
#  '94900',
#  '119900',
#  '129900',
#  '139900',
#  '129900',
#  '139900',
#  '149900',
#  '64900',
#  '74900',
#  '84900',
#  '99900',
#  '109900',
#  '119900',
#  '109900',
#  '119900',
#  '129900',
#  '89900',
#  '99900',
#  '99900',
#  '109900',
#  '119900',
#  '109900',
#  '119900',
#  '129900',
#  '64900',
#  '74900',
#  '84900',
# ...

# %%
df['Launched Price (India)']=p
p
# Out:
# ['79999',
#  '84999',
#  '89999',
#  '89999',
#  '94999',
#  '104999',
#  '99999',
#  '104999',
#  '114999',
#  '109999',
#  '114999',
#  '124999',
#  '74999',
#  '79999',
#  '89999',
#  '84999',
#  '94999',
#  '104999',
#  '99999',
#  '109999',
#  '119999',
#  '114999',
#  '124999',
#  '134999',
#  '69999',
#  '74999',
#  '84999',
#  '79999',
#  '84999',
#  '94999',
#  '109999',
#  '119999',
#  '134999',
#  '124999',
#  '134999',
#  '144999',
#  '69900',
#  '74900',
#  '84900',
#  '74900',
#  '84900',
#  '94900',
#  '119900',
#  '129900',
#  '139900',
#  '129900',
#  '139900',
#  '149900',
#  '69900',
#  '74900',
#  '84900',
#  '74900',
#  '84900',
#  '94900',
#  '119900',
#  '129900',
#  '139900',
#  '129900',
#  '139900',
#  '149900',
#  '64900',
#  '74900',
#  '84900',
#  '99900',
#  '109900',
#  '119900',
#  '109900',
#  '119900',
#  '129900',
#  '89900',
#  '99900',
#  '99900',
#  '109900',
#  '119900',
#  '109900',
#  '119900',
#  '129900',
#  '64900',
#  '74900',
#  '84900',
# ...

# %%
df['Launched Price (India)']=p
p
# Out:
# ['79999',
#  '84999',
#  '89999',
#  '89999',
#  '94999',
#  '104999',
#  '99999',
#  '104999',
#  '114999',
#  '109999',
#  '114999',
#  '124999',
#  '74999',
#  '79999',
#  '89999',
#  '84999',
#  '94999',
#  '104999',
#  '99999',
#  '109999',
#  '119999',
#  '114999',
#  '124999',
#  '134999',
#  '69999',
#  '74999',
#  '84999',
#  '79999',
#  '84999',
#  '94999',
#  '109999',
#  '119999',
#  '134999',
#  '124999',
#  '134999',
#  '144999',
#  '69900',
#  '74900',
#  '84900',
#  '74900',
#  '84900',
#  '94900',
#  '119900',
#  '129900',
#  '139900',
#  '129900',
#  '139900',
#  '149900',
#  '69900',
#  '74900',
#  '84900',
#  '74900',
#  '84900',
#  '94900',
#  '119900',
#  '129900',
#  '139900',
#  '129900',
#  '139900',
#  '149900',
#  '64900',
#  '74900',
#  '84900',
#  '99900',
#  '109900',
#  '119900',
#  '109900',
#  '119900',
#  '129900',
#  '89900',
#  '99900',
#  '99900',
#  '109900',
#  '119900',
#  '109900',
#  '119900',
#  '129900',
#  '64900',
#  '74900',
#  '84900',
# ...

# %%
df['Launched Price (India)']=df['Launched Price (India)'].astype('int')
df
# Out:
#     Company Name            Model Name Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174g   6GB             12MP
# 1          Apple       iPhone 16 256GB          174g   6GB             12MP
# 2          Apple       iPhone 16 512GB          174g   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203g   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203g   6GB             12MP
# ..           ...                   ...           ...   ...              ...
# 925         Poco          Pad 5G 128GB          571g   8GB              8MP
# 926         Poco          Pad 5G 256GB          571g   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239g  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239g  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239g  12GB  10MP, 4MP (UDC)
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Company Name               930 non-null    object
#  1   Model Name                 930 non-null    object
#  2   Mobile Weight              930 non-null    object
#  3   RAM                        930 non-null    object
#  4   Front Camera               930 non-null    object
#  5   Back Camera                930 non-null    object
#  6   Processor                  930 non-null    object
#  7   Battery Capacity           930 non-null    object
#  8   Screen Size                930 non-null    object
#  9   Launched Price (Pakistan)  930 non-null    int32
#  10  Launched Price (India)     930 non-null    int32
#  11  Launched Price (China)     930 non-null    object
#  12  Launched Price (USA)       930 non-null    object
# ...

# %%
s=df['Launched Price (India)']
s
# Out:
# 0       79999
# 1       84999
# 2       89999
# 3       89999
# 4       94999
#         ...
# 925     23999
# 926     25999
# 927    164999
# 928    176999
# 929    200999
# Name: Launched Price (India), Length: 930, dtype: int32

# %%
import matplotlib.pyplot as plot

# %%
s.plot.box()
# Out:
# <Axes: >

# %%
q1=np.quantile(s,0.25)
q1
# Out:
# 19999.0

# %%
q2=np.quantile(s,0.75)
q2
# Out:
# 74900.0

# %%
h=q2-q1
h
# Out:
# 54901.0

# %%
upper=q2+(1.5*h)
upper
# Out:
# 157251.5

# %%
lower=q1-(1.5*h)
lower
# Out:
# -62352.5

# %%
p=[]
for i in s:
    if(i>lower and i<upper):
        p.append(i)
p
# Out:
# [79999,
#  84999,
#  89999,
#  89999,
#  94999,
#  104999,
#  99999,
#  104999,
#  114999,
#  109999,
#  114999,
#  124999,
#  74999,
#  79999,
#  89999,
#  84999,
#  94999,
#  104999,
#  99999,
#  109999,
#  119999,
#  114999,
#  124999,
#  134999,
#  69999,
#  74999,
#  84999,
#  79999,
#  84999,
#  94999,
#  109999,
#  119999,
#  134999,
#  124999,
#  134999,
#  144999,
#  69900,
#  74900,
#  84900,
#  74900,
#  84900,
#  94900,
#  119900,
#  129900,
#  139900,
#  129900,
#  139900,
#  149900,
#  69900,
#  74900,
#  84900,
#  74900,
#  84900,
#  94900,
#  119900,
#  129900,
#  139900,
#  129900,
#  139900,
#  149900,
#  64900,
#  74900,
#  84900,
#  99900,
#  109900,
#  119900,
#  109900,
#  119900,
#  129900,
#  89900,
#  99900,
#  99900,
#  109900,
#  119900,
#  109900,
#  119900,
#  129900,
#  64900,
#  74900,
#  84900,
#  54900,
#  64900,
#  29900,
#  39900,
#  39900,
#  49900,
#  71900,
#  89900,
#  109900,
#  94900,
#  109900,
#  119900,
#  119900,
#  139900,
#  104900,
# ...

# %%
import pandas as pd
pd.Series(p).plot.box()
# Out:
# <Axes: >

# %%
g=df['Launched Price (China)']
t=list(g)
t
# Out:
# ['CNY 5,799',
#  'CNY 6,099',
#  'CNY 6,499',
#  'CNY 6,199',
#  'CNY 6,499',
#  'CNY 6,999',
#  'CNY 6,999',
#  'CNY 7,099',
#  'CNY 7,499',
#  'CNY 7,499',
#  'CNY 7,799',
#  'CNY 8,199',
#  'CNY 5,299',
#  'CNY 5,599',
#  'CNY 5,999',
#  'CNY 5,699',
#  'CNY 6,199',
#  'CNY 6,799',
#  'CNY 6,999',
#  'CNY 7,299',
#  'CNY 7,799',
#  'CNY 7,999',
#  'CNY 8,199',
#  'CNY 8,699',
#  'CNY 5,199',
#  'CNY 5,599',
#  'CNY 5,999',
#  'CNY 5,499',
#  'CNY 5,899',
#  'CNY 6,299',
#  'CNY 7,199',
#  'CNY 7,499',
#  'CNY 7,999',
#  'CNY 8,099',
#  'CNY 8,499',
#  'CNY 8,999',
#  'CNY 5,199',
#  'CNY 5,599',
#  'CNY 5,999',
#  'CNY 5,499',
#  'CNY 5,899',
#  'CNY 6,299',
#  'CNY 7,299',
#  'CNY 7,699',
#  'CNY 8,199',
#  'CNY 8,299',
#  'CNY 8,799',
#  'CNY 9,199',
#  'CNY 5,199',
#  'CNY 5,599',
#  'CNY 5,999',
#  'CNY 5,499',
#  'CNY 5,899',
#  'CNY 6,299',
#  'CNY 7,299',
#  'CNY 7,699',
#  'CNY 8,199',
#  'CNY 8,399',
#  'CNY 8,799',
#  'CNY 9,199',
#  'CNY 5,499',
#  'CNY 5,899',
# ...

# %%
p=[]
for i in t:
    h=""
    
    for j in i:
        if(j.isdigit()):
            h=h+j
    p.append(h)

# %%
p
# Out:
# ['5799',
#  '6099',
#  '6499',
#  '6199',
#  '6499',
#  '6999',
#  '6999',
#  '7099',
#  '7499',
#  '7499',
#  '7799',
#  '8199',
#  '5299',
#  '5599',
#  '5999',
#  '5699',
#  '6199',
#  '6799',
#  '6999',
#  '7299',
#  '7799',
#  '7999',
#  '8199',
#  '8699',
#  '5199',
#  '5599',
#  '5999',
#  '5499',
#  '5899',
#  '6299',
#  '7199',
#  '7499',
#  '7999',
#  '8099',
#  '8499',
#  '8999',
#  '5199',
#  '5599',
#  '5999',
#  '5499',
#  '5899',
#  '6299',
#  '7299',
#  '7699',
#  '8199',
#  '8299',
#  '8799',
#  '9199',
#  '5199',
#  '5599',
#  '5999',
#  '5499',
#  '5899',
#  '6299',
#  '7299',
#  '7699',
#  '8199',
#  '8399',
#  '8799',
#  '9199',
#  '5499',
#  '5899',
#  '6299',
#  '6999',
#  '7399',
#  '7999',
#  '7799',
#  '8199',
#  '8799',
#  '8388',
#  '8788',
#  '9188',
#  '9788',
#  '10388',
#  '10088',
#  '10688',
#  '11288',
#  '6299',
#  '6799',
#  '7299',
#  '3299',
#  '3699',
#  '2299',
#  '2699',
#  '3499',
#  '3799',
#  '6399',
#  '7199',
#  '7999',
#  '7999',
# ...

# %%
df['Launched Price (China)']=p
p
# Out:
# ['5799',
#  '6099',
#  '6499',
#  '6199',
#  '6499',
#  '6999',
#  '6999',
#  '7099',
#  '7499',
#  '7499',
#  '7799',
#  '8199',
#  '5299',
#  '5599',
#  '5999',
#  '5699',
#  '6199',
#  '6799',
#  '6999',
#  '7299',
#  '7799',
#  '7999',
#  '8199',
#  '8699',
#  '5199',
#  '5599',
#  '5999',
#  '5499',
#  '5899',
#  '6299',
#  '7199',
#  '7499',
#  '7999',
#  '8099',
#  '8499',
#  '8999',
#  '5199',
#  '5599',
#  '5999',
#  '5499',
#  '5899',
#  '6299',
#  '7299',
#  '7699',
#  '8199',
#  '8299',
#  '8799',
#  '9199',
#  '5199',
#  '5599',
#  '5999',
#  '5499',
#  '5899',
#  '6299',
#  '7299',
#  '7699',
#  '8199',
#  '8399',
#  '8799',
#  '9199',
#  '5499',
#  '5899',
#  '6299',
#  '6999',
#  '7399',
#  '7999',
#  '7799',
#  '8199',
#  '8799',
#  '8388',
#  '8788',
#  '9188',
#  '9788',
#  '10388',
#  '10088',
#  '10688',
#  '11288',
#  '6299',
#  '6799',
#  '7299',
#  '3299',
#  '3699',
#  '2299',
#  '2699',
#  '3499',
#  '3799',
#  '6399',
#  '7199',
#  '7999',
#  '7999',
# ...

# %%
df['Launched Price (China)']=df['Launched Price (China)'].astype('int')
df
# Out:
#     Company Name            Model Name Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174g   6GB             12MP
# 1          Apple       iPhone 16 256GB          174g   6GB             12MP
# 2          Apple       iPhone 16 512GB          174g   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203g   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203g   6GB             12MP
# ..           ...                   ...           ...   ...              ...
# 925         Poco          Pad 5G 128GB          571g   8GB              8MP
# 926         Poco          Pad 5G 256GB          571g   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239g  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239g  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239g  12GB  10MP, 4MP (UDC)
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Company Name               930 non-null    object
#  1   Model Name                 930 non-null    object
#  2   Mobile Weight              930 non-null    object
#  3   RAM                        930 non-null    object
#  4   Front Camera               930 non-null    object
#  5   Back Camera                930 non-null    object
#  6   Processor                  930 non-null    object
#  7   Battery Capacity           930 non-null    object
#  8   Screen Size                930 non-null    object
#  9   Launched Price (Pakistan)  930 non-null    int32
#  10  Launched Price (India)     930 non-null    int32
#  11  Launched Price (China)     930 non-null    int32
#  12  Launched Price (USA)       930 non-null    object
# ...

# %%
s=df['Launched Price (China)']
s
# Out:
# 0       5799
# 1       6099
# 2       6499
# 3       6199
# 4       6499
#        ...
# 925     2099
# 926     2299
# 927    13999
# 928    15999
# 929    17999
# Name: Launched Price (China), Length: 930, dtype: int32

# %%
s.plot.box()
# Out:
# <Axes: >

# %%
q1=np.quantile(s,0.25)
q1
# Out:
# 1699.25

# %%
q2=np.quantile(s,0.75)
q2
# Out:
# 5499.0

# %%
h=q2-q1
h
# Out:
# 3799.75

# %%
upper=q2+(1.5*h)
upper
# Out:
# 11198.625

# %%
lower=q1-(1.5*h)
lower
# Out:
# -4000.375

# %%
p=[]
for i in s:
    if(i>lower and i<upper):
        p.append(i)
p
# Out:
# [5799,
#  6099,
#  6499,
#  6199,
#  6499,
#  6999,
#  6999,
#  7099,
#  7499,
#  7499,
#  7799,
#  8199,
#  5299,
#  5599,
#  5999,
#  5699,
#  6199,
#  6799,
#  6999,
#  7299,
#  7799,
#  7999,
#  8199,
#  8699,
#  5199,
#  5599,
#  5999,
#  5499,
#  5899,
#  6299,
#  7199,
#  7499,
#  7999,
#  8099,
#  8499,
#  8999,
#  5199,
#  5599,
#  5999,
#  5499,
#  5899,
#  6299,
#  7299,
#  7699,
#  8199,
#  8299,
#  8799,
#  9199,
#  5199,
#  5599,
#  5999,
#  5499,
#  5899,
#  6299,
#  7299,
#  7699,
#  8199,
#  8399,
#  8799,
#  9199,
#  5499,
#  5899,
#  6299,
#  6999,
#  7399,
#  7999,
#  7799,
#  8199,
#  8799,
#  8388,
#  8788,
#  9188,
#  9788,
#  10388,
#  10088,
#  10688,
#  6299,
#  6799,
#  7299,
#  3299,
#  3699,
#  2299,
#  2699,
#  3499,
#  3799,
#  6399,
#  7199,
#  7999,
#  7999,
#  8699,
#  9199,
#  8699,
#  9199,
#  9799,
#  10399,
#  7499,
#  7999,
#  6199,
#  6999,
#  5799,
#  6199,
#  7299,
#  7999,
#  6199,
#  6799,
#  5499,
#  5999,
#  6599,
#  7199,
#  5999,
# ...

# %%
import pandas as pd
pd.Series(p).plot.box()
# Out:
# <Axes: >

# %%
g=df['Launched Price (USA)']
t=list(g)
t
# Out:
# ['USD 799',
#  'USD 849',
#  'USD 899',
#  'USD 899',
#  'USD 949',
#  'USD 999',
#  'USD 999',
#  'USD 1,049',
#  'USD 1,099',
#  'USD 1,099',
#  'USD 1,199',
#  'USD 1,299',
#  'USD 799',
#  'USD 849',
#  'USD 949',
#  'USD 899',
#  'USD 999',
#  'USD 1,049',
#  'USD 1,099',
#  'USD 1,199',
#  'USD 1,299',
#  'USD 1,199',
#  'USD 1,299',
#  'USD 1,399',
#  'USD 799',
#  'USD 849',
#  'USD 949',
#  'USD 899',
#  'USD 999',
#  'USD 1,049',
#  'USD 1,099',
#  'USD 1,199',
#  'USD 1,299',
#  'USD 1,199',
#  'USD 1,299',
#  'USD 1,399',
#  'USD 699',
#  'USD 799',
#  'USD 899',
#  'USD 799',
#  'USD 899',
#  'USD 999',
#  'USD 999',
#  'USD 1,099',
#  'USD 1,199',
#  'USD 1,099',
#  'USD 1,199',
#  'USD 1,399',
#  'USD 699',
#  'USD 799',
#  'USD 899',
#  'USD 799',
#  'USD 899',
#  'USD 999',
#  'USD 999',
#  'USD 1,099',
#  'USD 1,199',
#  'USD 1,099',
#  'USD 1,199',
#  'USD 1,399',
#  'USD 699',
#  'USD 799',
#  'USD 899',
#  'USD 999',
#  'USD 1,099',
#  'USD 1,199',
# ...

# %%
p=[]
for i in t:
    h=""
    
    for j in i:
        if(j.isdigit()):
            h=h+j
    p.append(h)

# %%
p
# Out:
# ['799',
#  '849',
#  '899',
#  '899',
#  '949',
#  '999',
#  '999',
#  '1049',
#  '1099',
#  '1099',
#  '1199',
#  '1299',
#  '799',
#  '849',
#  '949',
#  '899',
#  '999',
#  '1049',
#  '1099',
#  '1199',
#  '1299',
#  '1199',
#  '1299',
#  '1399',
#  '799',
#  '849',
#  '949',
#  '899',
#  '999',
#  '1049',
#  '1099',
#  '1199',
#  '1299',
#  '1199',
#  '1299',
#  '1399',
#  '699',
#  '799',
#  '899',
#  '799',
#  '899',
#  '999',
#  '999',
#  '1099',
#  '1199',
#  '1099',
#  '1199',
#  '1399',
#  '699',
#  '799',
#  '899',
#  '799',
#  '899',
#  '999',
#  '999',
#  '1099',
#  '1199',
#  '1099',
#  '1199',
#  '1399',
#  '699',
#  '799',
#  '899',
#  '999',
#  '1099',
#  '1199',
#  '1099',
#  '1199',
#  '1399',
#  '999',
#  '1099',
#  '999',
#  '1099',
#  '1299',
#  '1099',
#  '1249',
#  '1399',
#  '749',
#  '799',
#  '899',
#  '599',
#  '749',
#  '329',
#  '429',
#  '399',
#  '499',
#  '799',
#  '899',
#  '1099',
#  '999',
#  '1099',
#  '1299',
#  '1099',
#  '1199',
#  '1399',
# ...

# %%
df['Launched Price (USA)']=p
p
# Out:
# ['799',
#  '849',
#  '899',
#  '899',
#  '949',
#  '999',
#  '999',
#  '1049',
#  '1099',
#  '1099',
#  '1199',
#  '1299',
#  '799',
#  '849',
#  '949',
#  '899',
#  '999',
#  '1049',
#  '1099',
#  '1199',
#  '1299',
#  '1199',
#  '1299',
#  '1399',
#  '799',
#  '849',
#  '949',
#  '899',
#  '999',
#  '1049',
#  '1099',
#  '1199',
#  '1299',
#  '1199',
#  '1299',
#  '1399',
#  '699',
#  '799',
#  '899',
#  '799',
#  '899',
#  '999',
#  '999',
#  '1099',
#  '1199',
#  '1099',
#  '1199',
#  '1399',
#  '699',
#  '799',
#  '899',
#  '799',
#  '899',
#  '999',
#  '999',
#  '1099',
#  '1199',
#  '1099',
#  '1199',
#  '1399',
#  '699',
#  '799',
#  '899',
#  '999',
#  '1099',
#  '1199',
#  '1099',
#  '1199',
#  '1399',
#  '999',
#  '1099',
#  '999',
#  '1099',
#  '1299',
#  '1099',
#  '1249',
#  '1399',
#  '749',
#  '799',
#  '899',
#  '599',
#  '749',
#  '329',
#  '429',
#  '399',
#  '499',
#  '799',
#  '899',
#  '1099',
#  '999',
#  '1099',
#  '1299',
#  '1099',
#  '1199',
#  '1399',
# ...

# %%
df['Launched Price (USA)']=df['Launched Price (USA)'].astype('int')
df
# Out:
#     Company Name            Model Name Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174g   6GB             12MP
# 1          Apple       iPhone 16 256GB          174g   6GB             12MP
# 2          Apple       iPhone 16 512GB          174g   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203g   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203g   6GB             12MP
# ..           ...                   ...           ...   ...              ...
# 925         Poco          Pad 5G 128GB          571g   8GB              8MP
# 926         Poco          Pad 5G 256GB          571g   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239g  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239g  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239g  12GB  10MP, 4MP (UDC)
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Company Name               930 non-null    object
#  1   Model Name                 930 non-null    object
#  2   Mobile Weight              930 non-null    object
#  3   RAM                        930 non-null    object
#  4   Front Camera               930 non-null    object
#  5   Back Camera                930 non-null    object
#  6   Processor                  930 non-null    object
#  7   Battery Capacity           930 non-null    object
#  8   Screen Size                930 non-null    object
#  9   Launched Price (Pakistan)  930 non-null    int32
#  10  Launched Price (India)     930 non-null    int32
#  11  Launched Price (China)     930 non-null    int32
#  12  Launched Price (USA)       930 non-null    int32
# ...

# %%
s=df['Launched Price (USA)']
s
# Out:
# 0       799
# 1       849
# 2       899
# 3       899
# 4       949
#        ...
# 925     280
# 926     300
# 927    1899
# 928    1719
# 929    2259
# Name: Launched Price (USA), Length: 930, dtype: int32

# %%
s.plot.box()
# Out:
# <Axes: >

# %%
q1=np.quantile(s,0.25)
q1
# Out:
# 262.25

# %%
q2=np.quantile(s,0.75)
q2
# Out:
# 899.0

# %%
h=q2-q1
h
# Out:
# 636.75

# %%
upper=q2+(1.5*h)
upper
# Out:
# 1854.125

# %%
lower=q1-(1.5*h)
lower
# Out:
# -692.875

# %%
p=[]
for i in s:
    if(i>lower and i<upper):
        p.append(i)
p
# Out:
# [799,
#  849,
#  899,
#  899,
#  949,
#  999,
#  999,
#  1049,
#  1099,
#  1099,
#  1199,
#  1299,
#  799,
#  849,
#  949,
#  899,
#  999,
#  1049,
#  1099,
#  1199,
#  1299,
#  1199,
#  1299,
#  1399,
#  799,
#  849,
#  949,
#  899,
#  999,
#  1049,
#  1099,
#  1199,
#  1299,
#  1199,
#  1299,
#  1399,
#  699,
#  799,
#  899,
#  799,
#  899,
#  999,
#  999,
#  1099,
#  1199,
#  1099,
#  1199,
#  1399,
#  699,
#  799,
#  899,
#  799,
#  899,
#  999,
#  999,
#  1099,
#  1199,
#  1099,
#  1199,
#  1399,
#  699,
#  799,
#  899,
#  999,
#  1099,
#  1199,
#  1099,
#  1199,
#  1399,
#  999,
#  1099,
#  999,
#  1099,
#  1299,
#  1099,
#  1249,
#  1399,
#  749,
#  799,
#  899,
#  599,
#  749,
#  329,
#  429,
#  399,
#  499,
#  799,
#  899,
#  1099,
#  999,
#  1099,
#  1299,
#  1099,
#  1199,
#  1399,
#  1599,
#  1799,
#  1199,
#  1299,
#  899,
#  999,
#  799,
#  899,
#  1199,
#  1299,
#  899,
#  999,
#  799,
#  899,
#  1099,
#  1199,
#  799,
#  899,
#  699,
#  799,
#  1799,
#  999,
#  1099,
# ...

# %%
import pandas as pd
pd.Series(p).plot.box()
# Out:
# <Axes: >

# %%
g=df['Launched Price (Dubai)']
t=list(g)
t
# Out:
# ['AED 2,799',
#  'AED 2,999',
#  'AED 3,199',
#  'AED 3,199',
#  'AED 3,399',
#  'AED 3,599',
#  'AED 3,499',
#  'AED 3,699',
#  'AED 3,899',
#  'AED 3,799',
#  'AED 3,999',
#  'AED 4,199',
#  'AED 2,699',
#  'AED 2,999',
#  'AED 3,199',
#  'AED 3,199',
#  'AED 3,399',
#  'AED 3,599',
#  'AED 3,599',
#  'AED 3,799',
#  'AED 4,199',
#  'AED 3,899',
#  'AED 4,199',
#  'AED 4,399',
#  'AED 2,699',
#  'AED 2,999',
#  'AED 3,199',
#  'AED 3,199',
#  'AED 3,399',
#  'AED 3,599',
#  'AED 3,699',
#  'AED 3,899',
#  'AED 4,199',
#  'AED 3,999',
#  'AED 4,199',
#  'AED 4,499',
#  'AED 2,599',
#  'AED 2,999',
#  'AED 3,299',
#  'AED 2,999',
#  'AED 3,199',
#  'AED 3,599',
#  'AED 3,999',
#  'AED 4,199',
#  'AED 4,399',
#  'AED 4,199',
#  'AED 4,399',
#  'AED 4,599',
#  'AED 2,599',
#  'AED 2,999',
#  'AED 3,299',
#  'AED 2,999',
#  'AED 3,199',
#  'AED 3,599',
#  'AED 3,999',
#  'AED 4,199',
#  'AED 4,399',
#  'AED 4,199',
#  'AED 4,399',
#  'AED 4,599',
#  'AED 2,499',
#  'AED 2,999',
# ...

# %%
for i in t:
    h=""
    
    for j in i:
        if(j.isdigit()):
            h=h+j
    p.append(h)

# %%
p
# Out:
# [799,
#  849,
#  899,
#  899,
#  949,
#  999,
#  999,
#  1049,
#  1099,
#  1099,
#  1199,
#  1299,
#  799,
#  849,
#  949,
#  899,
#  999,
#  1049,
#  1099,
#  1199,
#  1299,
#  1199,
#  1299,
#  1399,
#  799,
#  849,
#  949,
#  899,
#  999,
#  1049,
#  1099,
#  1199,
#  1299,
#  1199,
#  1299,
#  1399,
#  699,
#  799,
#  899,
#  799,
#  899,
#  999,
#  999,
#  1099,
#  1199,
#  1099,
#  1199,
#  1399,
#  699,
#  799,
#  899,
#  799,
#  899,
#  999,
#  999,
#  1099,
#  1199,
#  1099,
#  1199,
#  1399,
#  699,
#  799,
#  899,
#  999,
#  1099,
#  1199,
#  1099,
#  1199,
#  1399,
#  999,
#  1099,
#  999,
#  1099,
#  1299,
#  1099,
#  1249,
#  1399,
#  749,
#  799,
#  899,
#  599,
#  749,
#  329,
#  429,
#  399,
#  499,
#  799,
#  899,
#  1099,
#  999,
#  1099,
#  1299,
#  1099,
#  1199,
#  1399,
#  1599,
#  1799,
#  1199,
#  1299,
#  899,
#  999,
#  799,
#  899,
#  1199,
#  1299,
#  899,
#  999,
#  799,
#  899,
#  1099,
#  1199,
#  799,
#  899,
#  699,
#  799,
#  1799,
#  999,
#  1099,
# ...

# %%
print(len(df))
print(len(p))
# Out:
# 930
# 1832

# %%
df['Launched Price (Dubai)'] = p[:len(df)]
p
# Out:
# [799,
#  849,
#  899,
#  899,
#  949,
#  999,
#  999,
#  1049,
#  1099,
#  1099,
#  1199,
#  1299,
#  799,
#  849,
#  949,
#  899,
#  999,
#  1049,
#  1099,
#  1199,
#  1299,
#  1199,
#  1299,
#  1399,
#  799,
#  849,
#  949,
#  899,
#  999,
#  1049,
#  1099,
#  1199,
#  1299,
#  1199,
#  1299,
#  1399,
#  699,
#  799,
#  899,
#  799,
#  899,
#  999,
#  999,
#  1099,
#  1199,
#  1099,
#  1199,
#  1399,
#  699,
#  799,
#  899,
#  799,
#  899,
#  999,
#  999,
#  1099,
#  1199,
#  1099,
#  1199,
#  1399,
#  699,
#  799,
#  899,
#  999,
#  1099,
#  1199,
#  1099,
#  1199,
#  1399,
#  999,
#  1099,
#  999,
#  1099,
#  1299,
#  1099,
#  1249,
#  1399,
#  749,
#  799,
#  899,
#  599,
#  749,
#  329,
#  429,
#  399,
#  499,
#  799,
#  899,
#  1099,
#  999,
#  1099,
#  1299,
#  1099,
#  1199,
#  1399,
#  1599,
#  1799,
#  1199,
#  1299,
#  899,
#  999,
#  799,
#  899,
#  1199,
#  1299,
#  899,
#  999,
#  799,
#  899,
#  1099,
#  1199,
#  799,
#  899,
#  699,
#  799,
#  1799,
#  999,
#  1099,
# ...

# %%
t = df['Launched Price (Dubai)'] 

p = []
for i in t:
    h = ""
    i = str(i)  
    for j in i:
        if j.isdigit():
            h += j
    p.append(h)

df['Launched Price (Dubai)'] = p

# %%
p
# Out:
# ['799',
#  '849',
#  '899',
#  '899',
#  '949',
#  '999',
#  '999',
#  '1049',
#  '1099',
#  '1099',
#  '1199',
#  '1299',
#  '799',
#  '849',
#  '949',
#  '899',
#  '999',
#  '1049',
#  '1099',
#  '1199',
#  '1299',
#  '1199',
#  '1299',
#  '1399',
#  '799',
#  '849',
#  '949',
#  '899',
#  '999',
#  '1049',
#  '1099',
#  '1199',
#  '1299',
#  '1199',
#  '1299',
#  '1399',
#  '699',
#  '799',
#  '899',
#  '799',
#  '899',
#  '999',
#  '999',
#  '1099',
#  '1199',
#  '1099',
#  '1199',
#  '1399',
#  '699',
#  '799',
#  '899',
#  '799',
#  '899',
#  '999',
#  '999',
#  '1099',
#  '1199',
#  '1099',
#  '1199',
#  '1399',
#  '699',
#  '799',
#  '899',
#  '999',
#  '1099',
#  '1199',
#  '1099',
#  '1199',
#  '1399',
#  '999',
#  '1099',
#  '999',
#  '1099',
#  '1299',
#  '1099',
#  '1249',
#  '1399',
#  '749',
#  '799',
#  '899',
#  '599',
#  '749',
#  '329',
#  '429',
#  '399',
#  '499',
#  '799',
#  '899',
#  '1099',
#  '999',
#  '1099',
#  '1299',
#  '1099',
#  '1199',
#  '1399',
# ...

# %%
df['Launched Price (Dubai)'] = df['Launched Price (Dubai)'].astype(int)
df
# Out:
#     Company Name            Model Name Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174g   6GB             12MP
# 1          Apple       iPhone 16 256GB          174g   6GB             12MP
# 2          Apple       iPhone 16 512GB          174g   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203g   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203g   6GB             12MP
# ..           ...                   ...           ...   ...              ...
# 925         Poco          Pad 5G 128GB          571g   8GB              8MP
# 926         Poco          Pad 5G 256GB          571g   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239g  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239g  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239g  12GB  10MP, 4MP (UDC)
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Company Name               930 non-null    object
#  1   Model Name                 930 non-null    object
#  2   Mobile Weight              930 non-null    object
#  3   RAM                        930 non-null    object
#  4   Front Camera               930 non-null    object
#  5   Back Camera                930 non-null    object
#  6   Processor                  930 non-null    object
#  7   Battery Capacity           930 non-null    object
#  8   Screen Size                930 non-null    object
#  9   Launched Price (Pakistan)  930 non-null    int32
#  10  Launched Price (India)     930 non-null    int32
#  11  Launched Price (China)     930 non-null    int32
#  12  Launched Price (USA)       930 non-null    int32
# ...

# %%
s=df['Launched Price (Dubai)']
s
# Out:
# 0       799
# 1       849
# 2       899
# 3       899
# 4       949
#        ...
# 925    4399
# 926    2699
# 927    2999
# 928    3199
# 929    3199
# Name: Launched Price (Dubai), Length: 930, dtype: int32

# %%
s.plot.box()
# Out:
# <Axes: >

# %%
q1=np.quantile(s,0.25)
q1
# Out:
# 262.25

# %%
q2=np.quantile(s,0.75)
q2
# Out:
# 899.0

# %%
h=q2-q1
h
# Out:
# 636.75

# %%
upper=q2+(1.5*h)
upper
# Out:
# 1854.125

# %%
lower=q1-(1.5*h)
lower
# Out:
# -692.875

# %%
p=[]
for i in s:
    if(i>lower and i<upper):
        p.append(i)
p
# Out:
# [799,
#  849,
#  899,
#  899,
#  949,
#  999,
#  999,
#  1049,
#  1099,
#  1099,
#  1199,
#  1299,
#  799,
#  849,
#  949,
#  899,
#  999,
#  1049,
#  1099,
#  1199,
#  1299,
#  1199,
#  1299,
#  1399,
#  799,
#  849,
#  949,
#  899,
#  999,
#  1049,
#  1099,
#  1199,
#  1299,
#  1199,
#  1299,
#  1399,
#  699,
#  799,
#  899,
#  799,
#  899,
#  999,
#  999,
#  1099,
#  1199,
#  1099,
#  1199,
#  1399,
#  699,
#  799,
#  899,
#  799,
#  899,
#  999,
#  999,
#  1099,
#  1199,
#  1099,
#  1199,
#  1399,
#  699,
#  799,
#  899,
#  999,
#  1099,
#  1199,
#  1099,
#  1199,
#  1399,
#  999,
#  1099,
#  999,
#  1099,
#  1299,
#  1099,
#  1249,
#  1399,
#  749,
#  799,
#  899,
#  599,
#  749,
#  329,
#  429,
#  399,
#  499,
#  799,
#  899,
#  1099,
#  999,
#  1099,
#  1299,
#  1099,
#  1199,
#  1399,
#  1599,
#  1799,
#  1199,
#  1299,
#  899,
#  999,
#  799,
#  899,
#  1199,
#  1299,
#  899,
#  999,
#  799,
#  899,
#  1099,
#  1199,
#  799,
#  899,
#  699,
#  799,
#  1799,
#  999,
#  1099,
# ...

# %%
import pandas as pd
pd.Series(p).plot.box()
# Out:
# <Axes: >

# %%
# !pip install openpyxl

# %%
df.to_csv("Mobile_info.csv", index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930 entries, 0 to 929
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Company Name               930 non-null    object
#  1   Model Name                 930 non-null    object
#  2   Mobile Weight              930 non-null    object
#  3   RAM                        930 non-null    object
#  4   Front Camera               930 non-null    object
#  5   Back Camera                930 non-null    object
#  6   Processor                  930 non-null    object
#  7   Battery Capacity           930 non-null    object
#  8   Screen Size                930 non-null    object
#  9   Launched Price (Pakistan)  930 non-null    int32
#  10  Launched Price (India)     930 non-null    int32
#  11  Launched Price (China)     930 non-null    int32
#  12  Launched Price (USA)       930 non-null    int32
# ...
